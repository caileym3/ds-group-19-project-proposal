# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
sonar_link <-"https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.mines"
sonar <- read_delim(sonar_link,delim = " ",skip = 10, col_names = FALSE)
sonar
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double(),
#   X3 = col_double(),
#   X4 = col_double(),
#   X5 = col_double(),
#   X6 = col_character()
# )
#
# Warning message:
# “110 parsing failures.
# row col  expected    actual                                                                                                           file
#  11  -- 6 columns 1 columns 'https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.mines'
#  22  -- 6 columns 1 columns 'https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.mines'
#  33  -- 6 columns 1 columns 'https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.mines'
#  44  -- 6 columns 1 columns 'https://archive.ics.uci.edu/ml/machine-learning-databases/undocumented/connectionist-bench/sonar/sonar.mines'
# ...
